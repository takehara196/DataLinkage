# %%
# !/usr/bin/env python
# -*- coding:utf-8 -*-
import pandas as pd
import numpy as np
import datetime
import io
import re
import itertools
import collections
from pylab import rcParams
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
raw_data_df = pd.read_excel("input/2021-11-09_promoV8NET-logdata.xlsx")
#raw_data_df = pd.read_excel("input/Taiyoubuhinten_v8LOG.xlsx")
#raw_data_df = pd.read_excel("input/Engineer_v8LOG.xlsx")
# 月日, 時刻カラムは必ず使用する為, カラム使用の判別に用いない
df = raw_data_df.drop(["月日", "時刻"], axis=1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16900/1814677301.py in <module>
# ----> 1 raw_data_df = pd.read_excel("input/2021-11-09_promoV8NET-logdata.xlsx")
#       2 #raw_data_df = pd.read_excel("input/Taiyoubuhinten_v8LOG.xlsx")
#       3 #raw_data_df = pd.read_excel("input/Engineer_v8LOG.xlsx")
#       4 # 月日, 時刻カラムは必ず使用する為, カラム使用の判別に用いない
#       5 df = raw_data_df.drop(["月日", "時刻"], axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1189                 ext = "xls"
#    1190             else:
# -> 1191                 ext = inspect_excel_format(
#    1192                     content_or_path=path_or_buffer, storage_options=storage_options
#    1193                 )
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in inspect_excel_format(content_or_path, storage_options)
#    1068         content_or_path = BytesIO(content_or_path)
#    1069
# -> 1070     with get_handle(
#    1071         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1072     ) as handle:
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: 'input/2021-11-09_promoV8NET-logdata.xlsx'

# %%
"""
カラム毎の欠損率確認
60%以上NULLのカラムは使用しない
"""
null_val = df.isnull().sum()
percent = 100 * df.isnull().sum() / len(df)
data_loss = pd.concat([null_val, percent], axis=1)
data_loss_columns = data_loss.rename(
    columns={0: '欠損数', 1: '欠損率'})
# 60％以上NULLのカラム
drop_col_list = list(data_loss_columns.query('欠損率 > 60').index)  # 入力値の欠損率が55.6%であった為, 本データでは使用する判断

# %%
"""
カラム毎の頻度確認
すべて同一の値のカラムは使用しない
"""
not_use_cols_list = []
for col in df.columns:
    df_appearance_rate = pd.DataFrame(df[col].value_counts())
    # すべて同一要素のカラムを取得
    if df_appearance_rate.shape[0] == 1:
        not_use_cols_list.append(col)
not_use_cols_list
# Out:
# ['サーバ', 'ポート', 'HTTPモード', 'ログインPID', '親ユーザ', 'アクセス結果', 'アクセス設定', '受信時間']

# %%
"""
手動で削除するカラム
設定ファイルなどしてもよい
"""
drop_cols = [
    "グローバルIP"  # 54.250.12.5, 3.115.81.216の2種類のみで特に見ていない値の為
]

# %%
drop_col_list.extend(not_use_cols_list)
# print(drop_col_list)
df = raw_data_df.drop(drop_col_list, axis=1)
df.to_csv("out/use_cols_df.csv", index=False)

# %%
df.head()
# Out:
#           月日        時刻       グローバルIP        コマンド    PID      子ユーザ  \
# 0 2021-11-09  16:04:43  3.115.81.216  価格検索（HTTP）  14200  61133205
# 1 2021-11-09  16:04:43  3.115.81.216  価格検索（HTTP）  14199  61133205
# 2 2021-11-09  16:04:43  3.115.81.216  価格検索（HTTP）  14198  61133205
# 3 2021-11-09  16:04:31   54.250.12.5  互換検索（HTTP）  14167  61791403
# 4 2021-11-09  16:04:26  3.115.81.216  価格検索（HTTP）  14157  61133205
#
#            アクセス状況  受信サイズ  受信数  返却数  返却サイズ  処理時間  応答時間         入力値  \
# 0  160/1321774/-1     68    5    1    336     1     1        U40B
# 1  159/1321774/-1     68    5    1    336     1     1        U40B
# 2  158/1321774/-1     72    5    1    340     1     1    MQ513048
# 3  274/3049825/-1     61    4    0    150     1     1  7289378A00
# 4  157/1321756/-1     70    5    1    355     1     1      J9061M
#
#                                         パラメータ等
# 0      parHinban=U40B parJunsei=0 parMakerNo=0
# 1      parHinban=U40B parJunsei=0 parMakerNo=0
# 2  parHinban=MQ513048 parJunsei=0 parMakerNo=0
# 3   parHinban=7289378A00 CallHinban=7289378A00
# 4    parHinban=J9061M parJunsei=0 parMakerNo=0

# %%
key_list = []
for raw in df["パラメータ等"]:
    # 半角スペースとイコールの間の文字列を取得する
    # \w: アルファベット、アンダーバー、数字
    p = r"(\w+)="
    r = re.findall(p, raw)
    key_list.append(r)
key_list = set(list(itertools.chain.from_iterable(key_list)))
print(key_list)
# Out:
# {'parHinban', 'KurumaInfo', 'parType', 'parHinmokuNos', 'parMakerNos', 'parJunsei', 'parHMCount', 'CallHinban', 'parKurumaNo', 'ParamList', 'parSyadaiNo', 'parMakerNo'}

# %%
for key in key_list:
    df['パラメータ等'] = df['パラメータ等'].str.replace(f'{key}', f',{key}')

# %%
# 先頭の1文字を削除(先頭の,を削除)
df["パラメータ等"] = df["パラメータ等"].str[1:]

# %%
# カンマで分割する
df_param = df['パラメータ等'].str.split(',', expand=True)
df_param
# Out:
#                          0                      1  \
# 0          parHinban=U40B            parJunsei=0
# 1          parHinban=U40B            parJunsei=0
# 2      parHinban=MQ513048            parJunsei=0
# 3    parHinban=7289378A00   CallHinban=7289378A00
# 4        parHinban=J9061M            parJunsei=0
# ..                     ...                    ...
# 995    parKurumaNo=141797          parHMCount=23
# 996    parKurumaNo=141793          parHMCount=23
# 997    parKurumaNo=140451          parHMCount=23
# 998    parKurumaNo=136422          parHMCount=23
# 999    parKurumaNo=147194          parHMCount=23
#
#                                                      2     3  \
# 0                                         parMakerNo=0  None
# 1                                         parMakerNo=0  None
# 2                                         parMakerNo=0  None
# 3                                                 None  None
# 4                                         parMakerNo=0  None
# ..                                                 ...   ...
# 995  parHinmokuNos=1020/1020/1020/1021/1021/1021/10...
# 996  parHinmokuNos=1020/1020/1020/1021/1021/1021/10...
# 997  parHinmokuNos=1020/1020/1020/1021/1021/1021/10...
# 998  parHinmokuNos=1020/1020/1020/1021/1021/1021/10...
# 999  parHinmokuNos=1020/1020/1020/1021/1021/1021/10...
#
#                                                      4              5
# 0                                                 None           None
# 1                                                 None           None
# 2                                                 None           None
# 3                                                 None           None
# 4                                                 None           None
# ..                                                 ...            ...
# 995  parMakerNos=3200/2260/4060/3200/2260/4060/2260...  parSyadaiNo=0
# 996  parMakerNos=3200/2260/4060/3200/2260/4060/2260...  parSyadaiNo=0
# 997  parMakerNos=3200/2260/4060/3200/2260/4060/2260...  parSyadaiNo=0
# 998  parMakerNos=3200/2260/4060/3200/2260/4060/2260...  parSyadaiNo=0
# 999  parMakerNos=3200/2260/4060/3200/2260/4060/2260...  parSyadaiNo=0
#
# [1000 rows x 6 columns]

# %%
df_ = pd.DataFrame()

for col in range(df_param.shape[1]):
    for key in key_list:
        df_[f'{key}_{col}'] = df_param[col].str.match(f'.*{key}=')
        # df_[f'{key}_{col}'] = df_param[col].str.match(f'.*{key}=*')
        df_.loc[df_[f'{key}_{col}'] == True, f'{key}_{col}'] = df_param[col]
df_.head()
df_.to_csv("./out/columns_name.csv")

# %%
# FalseをNullに置換
df_.replace(False, np.nan, inplace=True)
# すべて欠損の列を削除
df_.dropna(how='all', axis=1, inplace=True)
# サフィックスを削除
cols = df_.columns.str.replace('_.*', '', regex=True)
# カラム名変更
df_.columns = cols
df_.columns
df_
# Out:
#                  parHinban          parKurumaNo ParamList KurumaInfo parType  \
# 0          parHinban=U40B                   NaN       NaN        NaN     NaN
# 1          parHinban=U40B                   NaN       NaN        NaN     NaN
# 2      parHinban=MQ513048                   NaN       NaN        NaN     NaN
# 3    parHinban=7289378A00                   NaN       NaN        NaN     NaN
# 4        parHinban=J9061M                   NaN       NaN        NaN     NaN
# ..                     ...                  ...       ...        ...     ...
# 995                    NaN  parKurumaNo=141797        NaN        NaN     NaN
# 996                    NaN  parKurumaNo=141793        NaN        NaN     NaN
# 997                    NaN  parKurumaNo=140451        NaN        NaN     NaN
# 998                    NaN  parKurumaNo=136422        NaN        NaN     NaN
# 999                    NaN  parKurumaNo=147194        NaN        NaN     NaN
#
#         parJunsei      parHMCount             CallHinban  \
# 0    parJunsei=0              NaN                    NaN
# 1    parJunsei=0              NaN                    NaN
# 2    parJunsei=0              NaN                    NaN
# 3             NaN             NaN  CallHinban=7289378A00
# 4    parJunsei=0              NaN                    NaN
# ..            ...             ...                    ...
# 995           NaN  parHMCount=23                     NaN
# 996           NaN  parHMCount=23                     NaN
# 997           NaN  parHMCount=23                     NaN
# 998           NaN  parHMCount=23                     NaN
# 999           NaN  parHMCount=23                     NaN
#
#                                          parHinmokuNos CallHinban  \
# 0                                                  NaN        NaN
# 1                                                  NaN        NaN
# 2                                                  NaN        NaN
# 3                                                 None       None
# 4                                                  NaN        NaN
# ..                                                 ...        ...
# 995  parHinmokuNos=1020/1020/1020/1021/1021/1021/10...        NaN
# 996  parHinmokuNos=1020/1020/1020/1021/1021/1021/10...        NaN
# 997  parHinmokuNos=1020/1020/1020/1021/1021/1021/10...        NaN
# 998  parHinmokuNos=1020/1020/1020/1021/1021/1021/10...        NaN
# 999  parHinmokuNos=1020/1020/1020/1021/1021/1021/10...        NaN
#
#        parMakerNo                                        parMakerNos  \
# 0    parMakerNo=0                                               None
# 1    parMakerNo=0                                               None
# 2    parMakerNo=0                                               None
# 3            None                                               None
# 4    parMakerNo=0                                               None
# ..            ...                                                ...
# 995           NaN  parMakerNos=3200/2260/4060/3200/2260/4060/2260...
# 996           NaN  parMakerNos=3200/2260/4060/3200/2260/4060/2260...
# 997           NaN  parMakerNos=3200/2260/4060/3200/2260/4060/2260...
# 998           NaN  parMakerNos=3200/2260/4060/3200/2260/4060/2260...
# 999           NaN  parMakerNos=3200/2260/4060/3200/2260/4060/2260...
#
#        parSyadaiNo
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# ..             ...
# 995  parSyadaiNo=0
# 996  parSyadaiNo=0
# 997  parSyadaiNo=0
# 998  parSyadaiNo=0
# 999  parSyadaiNo=0
#
# [1000 rows x 13 columns]

# %%
# 同一カラム名が存在する場合は結合して一つのカラムにする
identifier = df_.columns.to_series().groupby(level=0).transform('cumcount')
identifier
# Out:
# parHinban        0
# parKurumaNo      0
# ParamList        0
# KurumaInfo       0
# parType          0
# parJunsei        0
# parHMCount       0
# CallHinban       0
# parHinmokuNos    0
# CallHinban       1
# parMakerNo       0
# parMakerNos      0
# parSyadaiNo      0
# dtype: int64

# %%
df_.columns = df_.columns.astype('string') + "_" + identifier.astype('string')
cols = df_.columns
cols
# Out:
# Index(['parHinban_0', 'parKurumaNo_0', 'ParamList_0', 'KurumaInfo_0',
#        'parType_0', 'parJunsei_0', 'parHMCount_0', 'CallHinban_0',
#        'parHinmokuNos_0', 'CallHinban_1', 'parMakerNo_0', 'parMakerNos_0',
#        'parSyadaiNo_0'],
#       dtype='object')

# %%
# Indexのサフィックスの数値から結合
# サフィックスの数値が0であれば何もしない
merge_col_list=[]
for col in df_.columns:
    # アンダーバーの数値が０なら何もしない
    if "_0" in col:
        pass
    # _数値が0以外であれば数値回だけ結合する
    else:
        col = col.split('_')[0]
        merge_col_list.append(col)

# サフィックスの数値の最大値取得して、例えば1なら1回結合する
merge_col_list
# Out:
# ['CallHinban']

# %%
# リストcolsを昇順に並び替える
l = cols.tolist()
l.sort()
print(l)
# サフィックスの最大値取得
sf = 2 # 最大値2とする

for col in cols:
    print(f'{col}')
# Out:
# ['CallHinban_0', 'CallHinban_1', 'KurumaInfo_0', 'ParamList_0', 'parHMCount_0', 'parHinban_0', 'parHinmokuNos_0', 'parJunsei_0', 'parKurumaNo_0', 'parMakerNo_0', 'parMakerNos_0', 'parSyadaiNo_0', 'parType_0']
# parHinban_0
# parKurumaNo_0
# ParamList_0
# KurumaInfo_0
# parType_0
# parJunsei_0
# parHMCount_0
# CallHinban_0
# parHinmokuNos_0
# CallHinban_1
# parMakerNo_0
# parMakerNos_0
# parSyadaiNo_0

# %%
print(merge_col_list)
# 動的にサフィックスの数値を取得

# 
sa=1

print(cols)


# _0と_1を結合

# _2を結合


for col in merge_col_list:
    #print(col)
    #print(range(sa))
    for s in range(sa):
        a = str(s)
        b = str(s+1)
        print(a)
        print(b)
        df_[f'{col}'] = df_[f'{col}_{a}'].str.cat(df_[f'{col}_{b}'], na_rep='')
        # カラム削除
        df_.drop([f"{col}_{a}", f"{col}_{b}"], axis=1, inplace=True)
df_
# Out:
# ['CallHinban']
# Index(['parHinban_0', 'parKurumaNo_0', 'ParamList_0', 'KurumaInfo_0',
#        'parType_0', 'parJunsei_0', 'parHMCount_0', 'CallHinban_0',
#        'parHinmokuNos_0', 'CallHinban_1', 'parMakerNo_0', 'parMakerNos_0',
#        'parSyadaiNo_0'],
#       dtype='object')
# 0
# 1
#                parHinban_0        parKurumaNo_0 ParamList_0 KurumaInfo_0  \
# 0          parHinban=U40B                   NaN         NaN          NaN
# 1          parHinban=U40B                   NaN         NaN          NaN
# 2      parHinban=MQ513048                   NaN         NaN          NaN
# 3    parHinban=7289378A00                   NaN         NaN          NaN
# 4        parHinban=J9061M                   NaN         NaN          NaN
# ..                     ...                  ...         ...          ...
# 995                    NaN  parKurumaNo=141797          NaN          NaN
# 996                    NaN  parKurumaNo=141793          NaN          NaN
# 997                    NaN  parKurumaNo=140451          NaN          NaN
# 998                    NaN  parKurumaNo=136422          NaN          NaN
# 999                    NaN  parKurumaNo=147194          NaN          NaN
#
#     parType_0   parJunsei_0    parHMCount_0  \
# 0         NaN  parJunsei=0              NaN
# 1         NaN  parJunsei=0              NaN
# 2         NaN  parJunsei=0              NaN
# 3         NaN           NaN             NaN
# 4         NaN  parJunsei=0              NaN
# ..        ...           ...             ...
# 995       NaN           NaN  parHMCount=23
# 996       NaN           NaN  parHMCount=23
# 997       NaN           NaN  parHMCount=23
# 998       NaN           NaN  parHMCount=23
# 999       NaN           NaN  parHMCount=23
#
#                                        parHinmokuNos_0  parMakerNo_0  \
# 0                                                  NaN  parMakerNo=0
# 1                                                  NaN  parMakerNo=0
# 2                                                  NaN  parMakerNo=0
# 3                                                 None          None
# 4                                                  NaN  parMakerNo=0
# ..                                                 ...           ...
# 995  parHinmokuNos=1020/1020/1020/1021/1021/1021/10...           NaN
# 996  parHinmokuNos=1020/1020/1020/1021/1021/1021/10...           NaN
# 997  parHinmokuNos=1020/1020/1020/1021/1021/1021/10...           NaN
# 998  parHinmokuNos=1020/1020/1020/1021/1021/1021/10...           NaN
# 999  parHinmokuNos=1020/1020/1020/1021/1021/1021/10...           NaN
#
#                                          parMakerNos_0  parSyadaiNo_0  \
# 0                                                 None           None
# 1                                                 None           None
# 2                                                 None           None
# 3                                                 None           None
# 4                                                 None           None
# ..                                                 ...            ...
# 995  parMakerNos=3200/2260/4060/3200/2260/4060/2260...  parSyadaiNo=0
# 996  parMakerNos=3200/2260/4060/3200/2260/4060/2260...  parSyadaiNo=0
# 997  parMakerNos=3200/2260/4060/3200/2260/4060/2260...  parSyadaiNo=0
# 998  parMakerNos=3200/2260/4060/3200/2260/4060/2260...  parSyadaiNo=0
# 999  parMakerNos=3200/2260/4060/3200/2260/4060/2260...  parSyadaiNo=0
#
#                 CallHinban
# 0
# 1
# 2
# 3    CallHinban=7289378A00
# 4
# ..                     ...
# 995
# 996
# 997
# 998
# 999
#
# [1000 rows x 12 columns]

# %%
df_
# Out:
#                parHinban_0        parKurumaNo_0 ParamList_0 KurumaInfo_0  \
# 0          parHinban=U40B                   NaN         NaN          NaN
# 1          parHinban=U40B                   NaN         NaN          NaN
# 2      parHinban=MQ513048                   NaN         NaN          NaN
# 3    parHinban=7289378A00                   NaN         NaN          NaN
# 4        parHinban=J9061M                   NaN         NaN          NaN
# ..                     ...                  ...         ...          ...
# 995                    NaN  parKurumaNo=141797          NaN          NaN
# 996                    NaN  parKurumaNo=141793          NaN          NaN
# 997                    NaN  parKurumaNo=140451          NaN          NaN
# 998                    NaN  parKurumaNo=136422          NaN          NaN
# 999                    NaN  parKurumaNo=147194          NaN          NaN
#
#     parType_0   parJunsei_0    parHMCount_0  \
# 0         NaN  parJunsei=0              NaN
# 1         NaN  parJunsei=0              NaN
# 2         NaN  parJunsei=0              NaN
# 3         NaN           NaN             NaN
# 4         NaN  parJunsei=0              NaN
# ..        ...           ...             ...
# 995       NaN           NaN  parHMCount=23
# 996       NaN           NaN  parHMCount=23
# 997       NaN           NaN  parHMCount=23
# 998       NaN           NaN  parHMCount=23
# 999       NaN           NaN  parHMCount=23
#
#                                        parHinmokuNos_0  parMakerNo_0  \
# 0                                                  NaN  parMakerNo=0
# 1                                                  NaN  parMakerNo=0
# 2                                                  NaN  parMakerNo=0
# 3                                                 None          None
# 4                                                  NaN  parMakerNo=0
# ..                                                 ...           ...
# 995  parHinmokuNos=1020/1020/1020/1021/1021/1021/10...           NaN
# 996  parHinmokuNos=1020/1020/1020/1021/1021/1021/10...           NaN
# 997  parHinmokuNos=1020/1020/1020/1021/1021/1021/10...           NaN
# 998  parHinmokuNos=1020/1020/1020/1021/1021/1021/10...           NaN
# 999  parHinmokuNos=1020/1020/1020/1021/1021/1021/10...           NaN
#
#                                          parMakerNos_0  parSyadaiNo_0  \
# 0                                                 None           None
# 1                                                 None           None
# 2                                                 None           None
# 3                                                 None           None
# 4                                                 None           None
# ..                                                 ...            ...
# 995  parMakerNos=3200/2260/4060/3200/2260/4060/2260...  parSyadaiNo=0
# 996  parMakerNos=3200/2260/4060/3200/2260/4060/2260...  parSyadaiNo=0
# 997  parMakerNos=3200/2260/4060/3200/2260/4060/2260...  parSyadaiNo=0
# 998  parMakerNos=3200/2260/4060/3200/2260/4060/2260...  parSyadaiNo=0
# 999  parMakerNos=3200/2260/4060/3200/2260/4060/2260...  parSyadaiNo=0
#
#                 CallHinban
# 0
# 1
# 2
# 3    CallHinban=7289378A00
# 4
# ..                     ...
# 995
# 996
# 997
# 998
# 999
#
# [1000 rows x 12 columns]

# %%
# サフィックスを削除
cols = df_.columns.str.replace('_.*', '', regex=True)
# カラム名変更
df_.columns = cols
# パラメータ名= を削除
for key in key_list:
    df_[f"{key}"] = df_[f"{key}"].str.replace(f"{key}=", "")
    #print(df_[f"{key}"])

# %%
df_
# Out:
#        parHinban parKurumaNo ParamList KurumaInfo parType parJunsei  \
# 0          U40B          NaN       NaN        NaN     NaN        0
# 1          U40B          NaN       NaN        NaN     NaN        0
# 2      MQ513048          NaN       NaN        NaN     NaN        0
# 3    7289378A00          NaN       NaN        NaN     NaN       NaN
# 4        J9061M          NaN       NaN        NaN     NaN        0
# ..           ...         ...       ...        ...     ...       ...
# 995          NaN     141797        NaN        NaN     NaN       NaN
# 996          NaN     141793        NaN        NaN     NaN       NaN
# 997          NaN     140451        NaN        NaN     NaN       NaN
# 998          NaN     136422        NaN        NaN     NaN       NaN
# 999          NaN     147194        NaN        NaN     NaN       NaN
#
#     parHMCount                                      parHinmokuNos parMakerNo  \
# 0          NaN                                                NaN          0
# 1          NaN                                                NaN          0
# 2          NaN                                                NaN          0
# 3          NaN                                               None       None
# 4          NaN                                                NaN          0
# ..         ...                                                ...        ...
# 995        23   1020/1020/1020/1021/1021/1021/1023/1025/1022/1...        NaN
# 996        23   1020/1020/1020/1021/1021/1021/1023/1025/1022/1...        NaN
# 997        23   1020/1020/1020/1021/1021/1021/1023/1025/1022/1...        NaN
# 998        23   1020/1020/1020/1021/1021/1021/1023/1025/1022/1...        NaN
# 999        23   1020/1020/1020/1021/1021/1021/1023/1025/1022/1...        NaN
#
#                                            parMakerNos parSyadaiNo  CallHinban
# 0                                                 None        None
# 1                                                 None        None
# 2                                                 None        None
# 3                                                 None        None  7289378A00
# 4                                                 None        None
# ..                                                 ...         ...         ...
# 995  3200/2260/4060/3200/2260/4060/2260/2260/3200/2...           0
# 996  3200/2260/4060/3200/2260/4060/2260/2260/3200/2...           0
# 997  3200/2260/4060/3200/2260/4060/2260/2260/3200/2...           0
# 998  3200/2260/4060/3200/2260/4060/2260/2260/3200/2...           0
# 999  3200/2260/4060/3200/2260/4060/2260/2260/3200/2...           0
#
# [1000 rows x 12 columns]

# %%
split_cols = []
# /区切りの要素が入るカラムを特定する
for c in cols:
    print(c)
    df_c = df_[df_[c].str.contains("/", na=False)]
    # レコード数取得
    # 0レコード以外カラム名をリストに格納する
    if df_c.shape[0] == 0:
        pass
    else:
        split_cols.append(c)
    #df_c.to_csv(f"./out/contain_slash_{c}.csv")
split_cols
# Out:
# parHinban
# parKurumaNo
# ParamList
# KurumaInfo
# parType
# parJunsei
# parHMCount
# parHinmokuNos
# parMakerNo
# parMakerNos
# parSyadaiNo
# CallHinban
# ['parHinban', 'ParamList', 'KurumaInfo', 'parHinmokuNos', 'parMakerNos']

# %%
split_cols
# Out:
# ['parHinban', 'ParamList', 'KurumaInfo', 'parHinmokuNos', 'parMakerNos']

# %%
for col in split_cols:
    df_[f"{col}"] = df_[f"{col}"].fillna("/")
    df_[f"{col}"] = df_[f"{col}"].replace('/', ',', regex=True)
    df_[f"{col}"] = df_[f"{col}"].str.split(',')
    #df_[f"{col}"].to_csv(f"out/{col}.csv", index=False)

# %%
df_
# Out:
#          parHinban parKurumaNo ParamList KurumaInfo parType parJunsei  \
# 0          [U40B ]         NaN      [, ]       [, ]     NaN        0
# 1          [U40B ]         NaN      [, ]       [, ]     NaN        0
# 2      [MQ513048 ]         NaN      [, ]       [, ]     NaN        0
# 3    [7289378A00 ]         NaN      [, ]       [, ]     NaN       NaN
# 4        [J9061M ]         NaN      [, ]       [, ]     NaN        0
# ..             ...         ...       ...        ...     ...       ...
# 995           [, ]     141797       [, ]       [, ]     NaN       NaN
# 996           [, ]     141793       [, ]       [, ]     NaN       NaN
# 997           [, ]     140451       [, ]       [, ]     NaN       NaN
# 998           [, ]     136422       [, ]       [, ]     NaN       NaN
# 999           [, ]     147194       [, ]       [, ]     NaN       NaN
#
#     parHMCount                                      parHinmokuNos parMakerNo  \
# 0          NaN                                               [, ]          0
# 1          NaN                                               [, ]          0
# 2          NaN                                               [, ]          0
# 3          NaN                                               [, ]       None
# 4          NaN                                               [, ]          0
# ..         ...                                                ...        ...
# 995        23   [1020, 1020, 1020, 1021, 1021, 1021, 1023, 102...        NaN
# 996        23   [1020, 1020, 1020, 1021, 1021, 1021, 1023, 102...        NaN
# 997        23   [1020, 1020, 1020, 1021, 1021, 1021, 1023, 102...        NaN
# 998        23   [1020, 1020, 1020, 1021, 1021, 1021, 1023, 102...        NaN
# 999        23   [1020, 1020, 1020, 1021, 1021, 1021, 1023, 102...        NaN
#
#                                            parMakerNos parSyadaiNo  CallHinban
# 0                                                 [, ]        None
# 1                                                 [, ]        None
# 2                                                 [, ]        None
# 3                                                 [, ]        None  7289378A00
# 4                                                 [, ]        None
# ..                                                 ...         ...         ...
# 995  [3200, 2260, 4060, 3200, 2260, 4060, 2260, 226...           0
# 996  [3200, 2260, 4060, 3200, 2260, 4060, 2260, 226...           0
# 997  [3200, 2260, 4060, 3200, 2260, 4060, 2260, 226...           0
# 998  [3200, 2260, 4060, 3200, 2260, 4060, 2260, 226...           0
# 999  [3200, 2260, 4060, 3200, 2260, 4060, 2260, 226...           0
#
# [1000 rows x 12 columns]

# %%
cols
# Out:
# Index(['parHinban', 'parKurumaNo', 'ParamList', 'KurumaInfo', 'parType',
#        'parJunsei', 'parHMCount', 'parHinmokuNos', 'parMakerNo', 'parMakerNos',
#        'parSyadaiNo', 'CallHinban'],
#       dtype='object')

# %%
split_cols = []
# /区切りの要素が入るカラムを特定する
for c in cols:
    print(c)
    df_c = df_[df_[c].str.contains("/", na=False)]
    # レコード数取得
    # 0レコード以外カラム名をリストに格納する
    if df_c.shape[0] == 0:
        pass
    else:
        split_cols.append(c)
    #df_c.to_csv(f"./out/contain_slash_{c}.csv")
split_cols

# %%
df_

# %%
# カンマ区切りで複数要素が入った列をリストで取得
split_cols

for col in split_cols:
    df_[f"{col}"] = df_[f"{col}"].fillna("/")
    df_[f"{col}"] = df_[f"{col}"].replace('/', ',', regex=True)
    df_[f"{col}"] = df_[f"{col}"].str.split(',')
    print(df_[f"{col}"])

# %%
# 同一カラムが存在する場合は結合して一つのカラムにする
#identifier = df_.columns.to_series().groupby(level=0).transform('cumcount')
#df_.columns = df_.columns.astype('string') + "_" + identifier.astype('string')
#df_['CallHinban_1'].to_csv("out/CallHinban_1.csv", index=False)
#df_['CallHinban_0'].to_csv("out/CallHinban_0.csv", index=False)
#df_['CallHinban'] = df_['CallHinban_0'].str.cat(df_['CallHinban_1'], na_rep='')
# カラム削除
#df_.drop(["CallHinban_0", "CallHinban_1"], axis=1, inplace=True)
# サフィックスを削除
#cols = df_.columns.str.replace('_.*', '', regex=True)
# カラム名変更
#df_.columns = cols
# パラメータ名= を削除
#for key in key_list:
#    df_[f"{key}"] = df_[f"{key}"].str.replace(f"{key}=", "")

# %%
# カンマ区切りで複数要素が入った列を集計
# ParamList, KurumaInfo, parHinmokuNos, parMakerNos
# / を , に変換
#split_cols = [
#    "ParamList", 
#    "KurumaInfo", 
#    "parHinmokuNos", 
#    "parMakerNos"
#]
for col in split_cols:
    df_[f"{col}"] = df_[f"{col}"].fillna("/")
    df_[f"{col}"] = df_[f"{col}"].replace('/', ',', regex=True)
    df_[f"{col}"] = df_[f"{col}"].str.split(',')
    df_[f"{col}"].to_csv(f"out/{col}.csv", index=False)

# %%
df_.to_csv("./out/df_.csv")
df_

# %% [markdown]
# ## 0. 目的
# - V8LOGデータ集計の進捗報告
#   - 集計方法の妥当性確認
#   - 可視化方法の確認
#
# ## 1. 進捗
#
# ### 前処理プログラム作成
# - 使用する列の抽出
#   - すべてNullのカラムは削除
#   - すべて同一のカラムは削除
#   - 過半数がNullのカラムは削除
#   - 不要な（あまり見ていない）カラムは削除
# - 「パラメータ等」列の分割
#   - 同一カラムに複数パラメータが入っている為、データ集計しやすいカラム、要素に分割する処理を作成
#
# ### 基礎集計
# - 単純集計
# - 可視化
#   - 棒グラフ
#   - ヒストグラム
#   - 時系列
#
# ## 2. 作成中
# - 同一子ユーザが短い間隔で検索した場合、除外するまたはまとめる
# -　相関のあるカラムの可視化
#   - 相関係数、有意差
# - 時間を指定して基礎集計、基本統計量を出力、可視化
#
#
# ## 3. 検証ポイント
# - レコード数を増やした場合、現在（1000レコード）と異なる特徴はみられるか
# - 同一子ユーザが短い間隔で検索した影響を除外した場合、現在と異なる特徴はみられるか
# - 相関（有意差）をみたい項目はあるか
# - 時系列で比較したい項目はあるか
#   - 今回は受信サイズ, 受信数でサンプル可視化
#   - 相関の高い項目を時系列で比較してみる等

# %%
raw_data_df = df_

# %% [markdown]
# ## 元データ

# %%
raw_data_df.head()
# Out:
#        parHinban parKurumaNo ParamList KurumaInfo parType parJunsei  \
# 0        [U40B ]         NaN      [, ]       [, ]     NaN        0
# 1        [U40B ]         NaN      [, ]       [, ]     NaN        0
# 2    [MQ513048 ]         NaN      [, ]       [, ]     NaN        0
# 3  [7289378A00 ]         NaN      [, ]       [, ]     NaN       NaN
# 4      [J9061M ]         NaN      [, ]       [, ]     NaN        0
#
#   parHMCount parHinmokuNos parMakerNo parMakerNos parSyadaiNo  CallHinban
# 0        NaN          [, ]          0        [, ]        None
# 1        NaN          [, ]          0        [, ]        None
# 2        NaN          [, ]          0        [, ]        None
# 3        NaN          [, ]       None        [, ]        None  7289378A00
# 4        NaN          [, ]          0        [, ]        None

# %%
raw_data_df.columns().head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-1329ce509070> in <module>
# ----> 1 raw_data_df.columns().head()
#
# TypeError: 'Index' object is not callable

# %%
# パラメータ等列
df_.head()
# Out:
#        parHinban parKurumaNo ParamList KurumaInfo parType parJunsei  \
# 0        [U40B ]         NaN      [, ]       [, ]     NaN        0
# 1        [U40B ]         NaN      [, ]       [, ]     NaN        0
# 2    [MQ513048 ]         NaN      [, ]       [, ]     NaN        0
# 3  [7289378A00 ]         NaN      [, ]       [, ]     NaN       NaN
# 4      [J9061M ]         NaN      [, ]       [, ]     NaN        0
#
#   parHMCount parHinmokuNos parMakerNo parMakerNos parSyadaiNo  CallHinban
# 0        NaN          [, ]          0        [, ]        None
# 1        NaN          [, ]          0        [, ]        None
# 2        NaN          [, ]          0        [, ]        None
# 3        NaN          [, ]       None        [, ]        None  7289378A00
# 4        NaN          [, ]          0        [, ]        None

# %% [markdown]
# ## 前処理済テーブル

# %%
df_p = pd.concat([df.drop('パラメータ等', axis=1), df_], axis=1)
df_p.head()
# Out:
#           月日        時刻       グローバルIP        コマンド    PID      子ユーザ  \
# 0 2021-11-09  16:04:43  3.115.81.216  価格検索（HTTP）  14200  61133205
# 1 2021-11-09  16:04:43  3.115.81.216  価格検索（HTTP）  14199  61133205
# 2 2021-11-09  16:04:43  3.115.81.216  価格検索（HTTP）  14198  61133205
# 3 2021-11-09  16:04:31   54.250.12.5  互換検索（HTTP）  14167  61791403
# 4 2021-11-09  16:04:26  3.115.81.216  価格検索（HTTP）  14157  61133205
#
#            アクセス状況  受信サイズ  受信数  返却数  ...  ParamList  KurumaInfo  parType  \
# 0  160/1321774/-1     68    5    1  ...       [, ]        [, ]      NaN
# 1  159/1321774/-1     68    5    1  ...       [, ]        [, ]      NaN
# 2  158/1321774/-1     72    5    1  ...       [, ]        [, ]      NaN
# 3  274/3049825/-1     61    4    0  ...       [, ]        [, ]      NaN
# 4  157/1321756/-1     70    5    1  ...       [, ]        [, ]      NaN
#
#   parJunsei parHMCount parHinmokuNos parMakerNo parMakerNos parSyadaiNo  \
# 0        0         NaN          [, ]          0        [, ]        None
# 1        0         NaN          [, ]          0        [, ]        None
# 2        0         NaN          [, ]          0        [, ]        None
# 3       NaN        NaN          [, ]       None        [, ]        None
# 4        0         NaN          [, ]          0        [, ]        None
#
#    CallHinban
# 0
# 1
# 2
# 3  7289378A00
# 4
#
# [5 rows x 26 columns]

# %% [markdown]
# ## 使用するカラム

# %%
pd.DataFrame(df_p.columns).rename(columns={0: 'use_cols'})
# Out:
#          use_cols
# 0              月日
# 1              時刻
# 2         グローバルIP
# 3            コマンド
# 4             PID
# 5            子ユーザ
# 6          アクセス状況
# 7           受信サイズ
# 8             受信数
# 9             返却数
# 10          返却サイズ
# 11           処理時間
# 12           応答時間
# 13            入力値
# 14      parHinban
# 15    parKurumaNo
# 16      ParamList
# 17     KurumaInfo
# 18        parType
# 19      parJunsei
# 20     parHMCount
# 21  parHinmokuNos
# 22     parMakerNo
# 23    parMakerNos
# 24    parSyadaiNo
# 25     CallHinban

# %%
df_p
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11584/2825050854.py in <module>
# ----> 1 df_p
#
# NameError: name 'df_p' is not defined

# %%
#df_p.to_csv("out/df_p_hist.csv", index=None)
#df_p_hist = pd.read_csv("out/df_p_hist.csv")

# %%
# !/usr/bin/env python
# -*- coding:utf-8 -*-
import pandas as pd
import numpy as np
import datetime
import io
import re
import itertools
import collections
from pylab import rcParams
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# 前処理済みテーブル
df_p = pd.read_csv("out/duplicate_excluded_df_2021-11-09_promoV8NET-logdata_1sec.csv", encoding="cp932")
#df_p = pd.read_csv("out/duplicate_excluded_df_Engineer_V8LOG.csv", encoding="cp932")
# df_p = pd.read_csv("out/duplicate_excluded_df_Taiyoubuhinten_v8LOG.csv", encoding="cp932")
df_p
# Out:
#              月日        時刻              子ユーザ  入力値   コマンド ParamList    LCResult  \
# 0    2021-07-10  13:41:23  Taiyoubuhinten-1  NaN  ログアウト  ['', '']  lcLoggedIn
# 1    2021-07-10  16:48:28  Taiyoubuhinten-1  NaN  ログアウト  ['', '']  lcLoggedIn
# 2    2021-07-12  17:51:16  Taiyoubuhinten-1  NaN  ログアウト  ['', '']  lcLoggedIn
# 3    2021-07-13  17:43:07  Taiyoubuhinten-1  NaN  ログアウト  ['', '']  lcLoggedIn
# 4    2021-07-14  17:45:27  Taiyoubuhinten-1  NaN  ログアウト  ['', '']  lcLoggedIn
# ..          ...       ...               ...  ...    ...       ...         ...
# 260  2022-01-06  15:16:10  Taiyoubuhinten-2  NaN  ログアウト  ['', '']  lcLoggedIn
# 261  2022-01-07  15:56:42  Taiyoubuhinten-2  NaN  ログアウト  ['', '']  lcLoggedIn
# 262  2022-01-08  17:07:01  Taiyoubuhinten-2  NaN  ログアウト  ['', '']  lcLoggedIn
# 263  2022-01-10  16:42:41  Taiyoubuhinten-2  NaN  ログアウト  ['', '']  lcLoggedIn
# 264  2022-01-11  15:16:00  Taiyoubuhinten-2  NaN  ログアウト  ['', '']  lcLoggedIn
#
#      KNo ResultList   KNoList WinVer KurumaInfo  Win64      UKey  parSyadaiNo  \
# 0    NaN   ['', '']  ['', '']    NaN   ['', '']    NaN  ['', '']          NaN
# 1    NaN   ['', '']  ['', '']    NaN   ['', '']    NaN  ['', '']          NaN
# 2    NaN   ['', '']  ['', '']    NaN   ['', '']    NaN  ['', '']          NaN
# 3    NaN   ['', '']  ['', '']    NaN   ['', '']    NaN  ['', '']          NaN
# 4    NaN   ['', '']  ['', '']    NaN   ['', '']    NaN  ['', '']          NaN
# ..   ...        ...       ...    ...        ...    ...       ...          ...
# 260  NaN   ['', '']  ['', '']    NaN   ['', '']    NaN  ['', '']          NaN
# 261  NaN   ['', '']  ['', '']    NaN   ['', '']    NaN  ['', '']          NaN
# 262  NaN   ['', '']  ['', '']    NaN   ['', '']    NaN  ['', '']          NaN
# 263  NaN   ['', '']  ['', '']    NaN   ['', '']    NaN  ['', '']          NaN
# 264  NaN   ['', '']  ['', '']    NaN   ['', '']    NaN  ['', '']          NaN
#
#     HinList MkrList                 date
# 0      ['']    ['']  2021-07-10 13:41:23
# 1      ['']    ['']  2021-07-10 16:48:28
# 2      ['']    ['']  2021-07-12 17:51:16
# 3      ['']    ['']  2021-07-13 17:43:07
# 4      ['']    ['']  2021-07-14 17:45:27
# ..      ...     ...                  ...
# 260    ['']    ['']  2022-01-06 15:16:10
# 261    ['']    ['']  2022-01-07 15:56:42
# 262    ['']    ['']  2022-01-08 17:07:01
# 263    ['']    ['']  2022-01-10 16:42:41
# 264    ['']    ['']  2022-01-11 15:16:00
#
# [265 rows x 18 columns]

# %% [markdown]
# # 基礎集計
# ---

# %% [markdown]
# ## 頻度
# ---

# %%
rcParams['figure.figsize'] = 20, 20
df_p.hist()
# Out:
# array([[<AxesSubplot:title={'center':'KNo'}>,
#         <AxesSubplot:title={'center':'Win64'}>],
#        [<AxesSubplot:title={'center':'parSyadaiNo'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ## 出現回数
# ---

# %% [markdown]
# ### 子ユーザ

# %%
df_p_child_user = df_p['子ユーザ'].value_counts(sort=True)
rcParams['figure.figsize'] = 10, 10
ax = df_p_child_user.iloc[:].plot(kind="barh")
ax.invert_yaxis()

# %% [markdown]
# ### コマンド

# %%
df_p_commands = df_p['コマンド'].value_counts(sort=True)
rcParams['figure.figsize'] = 5, 5
ax =df_p_commands.iloc[:].plot(kind="barh")
ax.invert_yaxis()
# Out:
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12525 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12450 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12454 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12531 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 65299 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 31309 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 31639 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 37096 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 21697 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 26908 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 32034 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 20114 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 25563 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 36554 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 36620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12525 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12464 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12450 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12454 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12488 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12531 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 65299 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 31309 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 31639 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 37096 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 21697 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 26908 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 32034 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 20114 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 25563 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 36554 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 36620 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### Taiyoubuhinten_v8LOGパラメータ
# - KNo
# - ResultList
# - LCResult
# - ParamList
# - KurumaInfo
# - KNoList	WinVer
# - Win64
# - parSyadaiNo
# - UKey
# - HinList
# - MkrList

# %%
ans = df_p['HinList']
ans
# Out:
# 0       ['']
# 1       ['']
# 2       ['']
# 3       ['']
# 4       ['']
#         ...
# 1025    ['']
# 1026    ['']
# 1027    ['']
# 1028    ['']
# 1029    ['']
# Name: HinList, Length: 1030, dtype: object

# %%
import collections
c = collections.Counter(ans)
c

# %%
df_param_name = df_p[["index"]].rename(columns={"index":"ParamList"})
df_counts = df_paramList[[0]].rename(columns={0:"counts"})
df_paramList = pd.concat([df_param_name, df_counts], axis=1)
df_paramList = df_paramList.sort_values("counts", ascending=False).reset_index(drop=True)
df_paramList
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3688/2995929353.py in <module>
# ----> 1 df_param_name = df_p[["index"]].rename(columns={"index":"ParamList"})
#       2 df_counts = df_paramList[[0]].rename(columns={0:"counts"})
#       3 df_paramList = pd.concat([df_param_name, df_counts], axis=1)
#       4 df_paramList = df_paramList.sort_values("counts", ascending=False).reset_index(drop=True)
#       5 df_paramList
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['index'], dtype='object')] are in the [columns]"

# %% [markdown]
# ## クロス集計
# ---

# %% [markdown]
# ### 子ユーザ別コマンド回数
# ---

# %%
display(pd.crosstab(df_p['子ユーザ'], df_p['コマンド']))
# Out:
# コマンド              ログアウト  ログイン３  互換検索  積算部品検索  車輌検索  部品検索
# 子ユーザ
# Taiyoubuhinten        0      1     0       0     0     0
# Taiyoubuhinten-1    322    116    27      95    11    27
# Taiyoubuhinten-2    386      1    20      10     6     8

# %% [markdown]
# # 「パラメータ等」列

# %% [markdown]
# ## 1. parHinban

# %%
commands = df_p["parHinban"].value_counts(sort=True)

rcParams['figure.figsize'] = 10, 10
ax = commands.iloc[:].plot(kind="barh")
ax.invert_yaxis()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'parHinban'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3688/647388058.py in <module>
# ----> 1 commands = df_p["parHinban"].value_counts(sort=True)
#       2
#       3 rcParams['figure.figsize'] = 10, 10
#       4 ax = commands.iloc[:].plot(kind="barh")
#       5 ax.invert_yaxis()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'parHinban'

# %%
rcParams['figure.figsize'] = 10, 10
ax = commands.iloc[:10].plot(kind="barh")
ax.invert_yaxis()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3688/3851119856.py in <module>
#       1 rcParams['figure.figsize'] = 10, 10
# ----> 2 ax = commands.iloc[:10].plot(kind="barh")
#       3 ax.invert_yaxis()
#
# NameError: name 'commands' is not defined

# %% [markdown]
# ## 2. parJunsei

# %%
commands = df_p["parJunsei"].value_counts(sort=True)

rcParams['figure.figsize'] = 10, 10
ax = commands.iloc[:].plot(kind="barh")
ax.invert_yaxis()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'parJunsei'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3688/791330605.py in <module>
# ----> 1 commands = df_p["parJunsei"].value_counts(sort=True)
#       2
#       3 rcParams['figure.figsize'] = 10, 10
#       4 ax = commands.iloc[:].plot(kind="barh")
#       5 ax.invert_yaxis()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'parJunsei'

# %% [markdown]
# ## 3. parType

# %%
commands = df_p["parType"].value_counts(sort=True)

rcParams['figure.figsize'] = 10, 10
ax = commands.iloc[:].plot(kind="barh")
ax.invert_yaxis()

# %% [markdown]
# ## 4. parHMCount

# %%
commands = df_p["parHMCount"].value_counts(sort=True)

rcParams['figure.figsize'] = 10, 10
ax = commands.iloc[:].plot(kind="barh")
ax.invert_yaxis()

# %% [markdown]
# ## 5. parMakerNo

# %%
commands = df_p["parMakerNo"].value_counts(sort=True)

rcParams['figure.figsize'] = 10, 10
ax = commands.iloc[:].plot(kind="barh")
ax.invert_yaxis()

# %% [markdown]
# ## 6. parSyadaiNo

# %%
commands = df_p["parSyadaiNo"].value_counts(sort=True)

rcParams['figure.figsize'] = 10, 10
ax = commands.iloc[:].plot(kind="barh")
ax.invert_yaxis()

# %% [markdown]
# ## 7. CallHinban

# %%
# 空文字列をNaNに置換
df_p["CallHinban"].replace(r'^\s*$', np.nan, regex=True, inplace=True)
# nanを削除
df_p["CallHinban"]= df_p["CallHinban"].dropna(how='any')
df_p["CallHinban"]

commands = df_p["CallHinban"].value_counts(sort=True)

rcParams['figure.figsize'] = 10, 10
ax = commands.iloc[:].plot(kind="barh")
ax.invert_yaxis()

# %%
rcParams['figure.figsize'] = 10, 10
ax = commands.iloc[:10].plot(kind="barh")
ax.invert_yaxis()

# %% [markdown]
# ## 8. parKurumaNo

# %%
commands = df_p["parKurumaNo"].value_counts(sort=True)

rcParams['figure.figsize'] = 10, 10
ax = commands.iloc[:].plot(kind="barh")
ax.invert_yaxis()

# %%
rcParams['figure.figsize'] = 10, 10
ax = commands.iloc[:10].plot(kind="barh")
ax.invert_yaxis()

# %%
commands = df_p["parKurumaNo"].value_counts(sort=True)
commands
# Out:
# 126188.0    12
# 102277.0    10
# 116439.0     4
# 116440.0     4
# 143744.0     2
# 116158.0     2
# 136183.0     2
# 122591.0     1
# 134827.0     1
# 150421.0     1
# 147181.0     1
# 137506.0     1
# 136521.0     1
# 119010.0     1
# 139557.0     1
# 90340.0      1
# 142449.0     1
# 113112.0     1
# 142921.0     1
# 134818.0     1
# 106060.0     1
# 116055.0     1
# 46611.0      1
# 147906.0     1
# 136798.0     1
# Name: parKurumaNo, dtype: int64

# %%
# #特定の文'列を削除

# df_p["ParamList"] = df_p["ParamList"].translate(str.maketrans({'[': '', ']': ''}))
# df_p["ParamList"]

# %%
commands = df_p["ParamList"].value_counts(sort=True)
commands
# Out:
# ['', '']                      170
# ['15096', '0001', '', ' ']      7
# ['16011', '0011', '', ' ']      2
# ['16010', '0014', '', ' ']      2
# ['', '', '176042', ' ']         2
# ['', '', 'DBA4GCHVS', ' ']      2
# ['17714', '007', '', ' ']       2
# ['', '', 'TRH200', ' ']         2
# ['06930', '0010', '', ' ']      1
# ['18183', '0001', '', ' ']      1
# ['15702', '0604', '', ' ']      1
# ['15421', '013', '', ' ']       1
# ['', '', 'KEA5W', ' ']          1
# ['', '', 'KE5AW', ' ']          1
# ['', '', 'ZM6', ' ']            1
# ['', '', '1760422', ' ']        1
# ['10417', '0013', '', ' ']      1
# ['', '', 'FC7JKKA', ' ']        1
# ['15199', '0604', '', ' ']      1
# ['', '', '11420', ' ']          1
# ['', '', 'FC7JKAA', ' ']        1
# ['', '', 'FBA20', ' ']          1
# ['', '', 'FAB', ' ']            1
# ['18096', '0004', '', ' ']      1
# ['15197', '0017', '', ' ']      1
# ['16294', '0036', '', ' ']      1
# ['15997', '1050', '', ' ']      1
# ['09223', '0227', '', ' ']      1
# ['', '', '1A16', ' ']           1
# ['12615', '0005', '', ' ']      1
# ['11944', '0008', '', ' ']      1
# ['09190', '0174', '', ' ']      1
# ['16606', '0094', '', ' ']      1
# ['11672', '0020', '', ' ']      1
# ['16806', '0004', '', ' ']      1
# ['', '', 'S500P', ' ']          1
# ['16605', '0325', '', ' ']      1
# ['11220', '0036', '', ' ']      1
# ['15982', '0007', '', ' ']      1
# ['18094', '0615', '', ' ']      1
# ['15983', '0225', '', ' ']      1
# ['', '', 'DA64V', ' ']          1
# ['16010', '0011', '', ' ']      1
# ['17007', '0005', '', ' ']      1
# ['17338', '0003', '', ' ']      1
# ['', '', 'SD29T', ' ']          1
# ['16294', '0025', '', ' ']      1
# ['15159', '0001', '', ' ']      1
# Name: ParamList, dtype: int64

# %%
# # 複数存在するパラメータの出現回数（/区切りの要素が存在するパラメータ）
# ans = sum(df_p["ParamList"], [])
# c = collections.Counter(ans)
# df_paramList = pd.DataFrame.from_dict(c, orient='index').reset_index()
# # 空文字列をNaNに置換
# df_paramList.replace(r'^\s*$', np.nan, regex=True, inplace=True)
# # nanを削除
# df_paramList=df_paramList.dropna(how='any')
# # 半角スペースを削除
# df_paramList=df_paramList[~df_paramList['index'].str.contains(' ')]
# # カラム名変更

# df_param_name = df_paramList[["index"]].rename(columns={"index":"KurumaInfo"})
# df_counts = df_paramList[[0]].rename(columns={0:"counts"})
# df_paramList = pd.concat([df_param_name, df_counts], axis=1)
# df_paramList = df_paramList.sort_values("counts", ascending=False).reset_index(drop=True)
# df_paramList

# %%
commands = df_p["ParamList"].value_counts(sort=True)

rcParams['figure.figsize'] = 10, 10
ax = commands.iloc[:].plot(kind="barh")
ax.invert_yaxis()

# %% [markdown]
# # 複数存在するパラメータ（ / で区切られているパラメータ）

# %% [markdown]
# ## 9. ParamList
# ---

# %%
# # 複数存在するパラメータの出現回数（/区切りの要素が存在するパラメータ）
# ans = sum(df_['ParamList'], [])
# c = collections.Counter(ans)
# df_paramList = pd.DataFrame.from_dict(c, orient='index').reset_index()
# # 空文字列をNaNに置換
# df_paramList.replace(r'^\s*$', np.nan, regex=True, inplace=True)
# # nanを削除
# df_paramList=df_paramList.dropna(how='any')
# # 半角スペースを削除
# df_paramList=df_paramList[~df_paramList['index'].str.contains(' ')]
# # カラム名変更

# df_param_name = df_paramList[["index"]].rename(columns={"index":"ParamList"})
# df_counts = df_paramList[[0]].rename(columns={0:"counts"})
# df_paramList = pd.concat([df_param_name, df_counts], axis=1)
# df_paramList = df_paramList.sort_values("counts", ascending=False).reset_index(drop=True)
# df_paramList

# %% [markdown]
# ### ParamList全カウント

# %%
df_paramList = df_paramList.set_index('ParamList')
rcParams['figure.figsize'] = 15, 15
ax = df_paramList.iloc[:].plot(kind="barh")
ax.invert_yaxis()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16900/2820564121.py in <module>
# ----> 1 df_paramList = df_paramList.set_index('ParamList')
#       2 rcParams['figure.figsize'] = 15, 15
#       3 ax = df_paramList.iloc[:].plot(kind="barh")
#       4 ax.invert_yaxis()
#
# NameError: name 'df_paramList' is not defined

# %% [markdown]
# ### ParamListトップ10

# %%
rcParams['figure.figsize'] = 10, 10
ax = df_paramList.iloc[:10].plot(kind="barh")
ax.invert_yaxis()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16900/3243134293.py in <module>
#       1 rcParams['figure.figsize'] = 10, 10
# ----> 2 ax = df_paramList.iloc[:10].plot(kind="barh")
#       3 ax.invert_yaxis()
#
# NameError: name 'df_paramList' is not defined

# %% [markdown]
# ## 10. KurumaInfo
# ---

# %%
# # 複数存在するパラメータの出現回数（/区切りの要素が存在するパラメータ）
# ans = sum(df_['KurumaInfo'], [])
# c = collections.Counter(ans)
# df_paramList = pd.DataFrame.from_dict(c, orient='index').reset_index()
# # 空文字列をNaNに置換
# df_paramList.replace(r'^\s*$', np.nan, regex=True, inplace=True)
# # nanを削除
# df_paramList=df_paramList.dropna(how='any')
# # 半角スペースを削除
# df_paramList=df_paramList[~df_paramList['index'].str.contains(' ')]
# # カラム名変更

# df_param_name = df_paramList[["index"]].rename(columns={"index":"KurumaInfo"})
# df_counts = df_paramList[[0]].rename(columns={0:"counts"})
# df_paramList = pd.concat([df_param_name, df_counts], axis=1)
# df_paramList = df_paramList.sort_values("counts", ascending=False).reset_index(drop=True)
# df_paramList
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16900/4134015300.py in <module>
#       1 # 複数存在するパラメータの出現回数（/区切りの要素が存在するパラメータ）
# ----> 2 ans = sum(df_['KurumaInfo'], [])
#       3 c = collections.Counter(ans)
#       4 df_paramList = pd.DataFrame.from_dict(c, orient='index').reset_index()
#       5 # 空文字列をNaNに置換
#
# NameError: name 'df_' is not defined

# %% [markdown]
# ### KurumaInfo全カウント

# %%
df_paramList = df_paramList.set_index('KurumaInfo')
rcParams['figure.figsize'] = 20, 20
ax = df_paramList.iloc[:].plot(kind="barh")
ax.invert_yaxis()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16900/2834312480.py in <module>
# ----> 1 df_paramList = df_paramList.set_index('KurumaInfo')
#       2 rcParams['figure.figsize'] = 20, 20
#       3 ax = df_paramList.iloc[:].plot(kind="barh")
#       4 ax.invert_yaxis()
#
# NameError: name 'df_paramList' is not defined

# %% [markdown]
# ### KurumaInfoトップ１０

# %%
rcParams['figure.figsize'] = 10, 10
ax = df_paramList.iloc[:10].plot(kind="barh")
ax.invert_yaxis()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16900/3243134293.py in <module>
#       1 rcParams['figure.figsize'] = 10, 10
# ----> 2 ax = df_paramList.iloc[:10].plot(kind="barh")
#       3 ax.invert_yaxis()
#
# NameError: name 'df_paramList' is not defined

# %% [markdown]
# ## 11. parHinmokuNos
# ---

# %%
# # 複数存在するパラメータの出現回数（/区切りの要素が存在するパラメータ）
# ans = sum(df_['parHinmokuNos'], [])
# c = collections.Counter(ans)
# df_paramList = pd.DataFrame.from_dict(c, orient='index').reset_index()
# # 空文字列をNaNに置換
# df_paramList.replace(r'^\s*$', np.nan, regex=True, inplace=True)
# # nanを削除
# df_paramList=df_paramList.dropna(how='any')
# # 半角スペースを削除
# df_paramList=df_paramList[~df_paramList['index'].str.contains(' ')]
# # カラム名変更

# df_param_name = df_paramList[["index"]].rename(columns={"index":"parHinmokuNos"})
# df_counts = df_paramList[[0]].rename(columns={0:"counts"})
# df_paramList = pd.concat([df_param_name, df_counts], axis=1)
# df_paramList = df_paramList.sort_values("counts", ascending=False).reset_index(drop=True)
# df_paramList
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16900/1442033414.py in <module>
#       1 # 複数存在するパラメータの出現回数（/区切りの要素が存在するパラメータ）
# ----> 2 ans = sum(df_['parHinmokuNos'], [])
#       3 c = collections.Counter(ans)
#       4 df_paramList = pd.DataFrame.from_dict(c, orient='index').reset_index()
#       5 # 空文字列をNaNに置換
#
# NameError: name 'df_' is not defined

# %% [markdown]
# ### parHinmokuNos全カウント

# %%
df_paramList = df_paramList.set_index('parHinmokuNos')
rcParams['figure.figsize'] = 20, 20
ax = df_paramList.iloc[:].plot(kind="barh")
ax.invert_yaxis()

# %% [markdown]
# ### parHinmokuNosトップ10

# %%
rcParams['figure.figsize'] = 10, 10
ax = df_paramList.iloc[:10].plot(kind="barh")
ax.invert_yaxis()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16900/3243134293.py in <module>
#       1 rcParams['figure.figsize'] = 10, 10
# ----> 2 ax = df_paramList.iloc[:10].plot(kind="barh")
#       3 ax.invert_yaxis()
#
# NameError: name 'df_paramList' is not defined

# %% [markdown]
# ## 12. parMakerNos

# %%
# # 複数存在するパラメータの出現回数（/区切りの要素が存在するパラメータ）
# ans = sum(df_['parMakerNos'], [])
# c = collections.Counter(ans)
# df_paramList = pd.DataFrame.from_dict(c, orient='index').reset_index()
# # 空文字列をNaNに置換
# df_paramList.replace(r'^\s*$', np.nan, regex=True, inplace=True)
# # nanを削除
# df_paramList=df_paramList.dropna(how='any')
# # 半角スペースを削除
# df_paramList=df_paramList[~df_paramList['index'].str.contains(' ')]
# # カラム名変更

# df_param_name = df_paramList[["index"]].rename(columns={"index":"parMakerNos"})
# df_counts = df_paramList[[0]].rename(columns={0:"counts"})
# df_paramList = pd.concat([df_param_name, df_counts], axis=1)
# df_paramList = df_paramList.sort_values("counts", ascending=False).reset_index(drop=True)
# df_paramList

# %% [markdown]
# ### parMakerNos全カウント

# %%
df_paramList = df_paramList.set_index('parMakerNos')
rcParams['figure.figsize'] = 20, 20
ax = df_paramList.iloc[:].plot(kind="barh")
ax.invert_yaxis()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16900/1624113155.py in <module>
# ----> 1 df_paramList = df_paramList.set_index('parMakerNos')
#       2 rcParams['figure.figsize'] = 20, 20
#       3 ax = df_paramList.iloc[:].plot(kind="barh")
#       4 ax.invert_yaxis()
#
# NameError: name 'df_paramList' is not defined

# %% [markdown]
# ### parMakerNosトップ10

# %%
rcParams['figure.figsize'] = 10, 10
ax = df_paramList.iloc[:10].plot(kind="barh")
ax.invert_yaxis()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16900/3243134293.py in <module>
#       1 rcParams['figure.figsize'] = 10, 10
# ----> 2 ax = df_paramList.iloc[:10].plot(kind="barh")
#       3 ax.invert_yaxis()
#
# NameError: name 'df_paramList' is not defined

# %% [markdown]
# # 基本統計量
# ---

# %% [markdown]
# 基本統計量はもう少し前処理をした後に行う方がよいと考える為、今回未実施

# %%
df_p
# Out:
#              月日        時刻      子ユーザ          入力値        コマンド  parKurumaNo  \
# 0    2021-11-09  15:02:16    221002  122905R0004  価格検索（HTTP）          NaN
# 1    2021-11-09  15:02:32    221002  122905R0004  価格検索（HTTP）          NaN
# 2    2021-11-09  15:07:49    221002  122905R0004  価格検索（HTTP）          NaN
# 3    2021-11-09  15:11:40    221002        SD29T  車輌検索（HTTP）          NaN
# 4    2021-11-09  15:11:57    221002   R20618300E  価格検索（HTTP）          NaN
# ..          ...       ...       ...          ...         ...          ...
# 224  2021-11-09  16:04:00  61133205   17714-0007  車輌検索（HTTP）          NaN
# 225  2021-11-09  16:04:26  61133205       J9061M  価格検索（HTTP）          NaN
# 226  2021-11-09  16:04:43  61133205         U40B  価格検索（HTTP）          NaN
# 227  2021-11-09  16:04:43  61133205         U40B  価格検索（HTTP）          NaN
# 228  2021-11-09  16:04:31  61791403   7289378A00  互換検索（HTTP）          NaN
#
#               parHinban                  ParamList  parJunsei  \
# 0    ['12290-5R0-004 ']                   ['', '']        0.0
# 1    ['12290-5R0-004 ']                   ['', '']        0.0
# 2    ['12290-5R0-004 ']                   ['', '']        0.0
# 3              ['', '']     ['', '', 'SD29T', ' ']        NaN
# 4     ['R206-18-300E ']                   ['', '']        0.0
# ..                  ...                        ...        ...
# 224            ['', '']  ['17714', '007', '', ' ']        NaN
# 225         ['J9061M ']                   ['', '']        0.0
# 226           ['U40B ']                   ['', '']        0.0
# 227           ['U40B ']                   ['', '']        0.0
# 228     ['7289378A00 ']                   ['', '']        NaN
#
#                                             KurumaInfo parType  parHMCount  \
# 0                                             ['', '']     NaN         NaN
# 1                                             ['', '']     NaN         NaN
# 2                                             ['', '']     NaN         NaN
# 3    ['24455', '4', 'ﾏﾂﾀﾞ', '8', 'ﾌﾞﾛｰﾆｨ2200DSL', '...     NaN         NaN
# 4                                             ['', '']     NaN         NaN
# ..                                                 ...     ...         ...
# 224  ['141488', '3', '三菱', '23', 'ﾐﾆｷｬﾌﾞ 660 ﾊﾞﾝ', ...     NaN         NaN
# 225                                           ['', '']     NaN         NaN
# 226                                           ['', '']     NaN         NaN
# 227                                           ['', '']     NaN         NaN
# 228                                           ['', '']     NaN         NaN
#
#      parMakerNo parHinmokuNos parMakerNos  parSyadaiNo  CallHinban  \
# 0           0.0      ['', '']    ['', '']          NaN         NaN
# 1           0.0      ['', '']    ['', '']          NaN         NaN
# 2           0.0      ['', '']    ['', '']          NaN         NaN
# 3           NaN      ['', '']    ['', '']          NaN         NaN
# 4           0.0      ['', '']    ['', '']          NaN         NaN
# ..          ...           ...         ...          ...         ...
# 224         NaN      ['', '']    ['', '']          NaN         NaN
# 225         0.0      ['', '']    ['', '']          NaN         NaN
# 226         0.0      ['', '']    ['', '']          NaN         NaN
# 227         0.0      ['', '']    ['', '']          NaN         NaN
# 228         NaN      ['', '']    ['', '']          NaN  7289378A00
#
#                     date
# 0    2021-11-09 15:02:16
# 1    2021-11-09 15:02:32
# 2    2021-11-09 15:07:49
# 3    2021-11-09 15:11:40
# 4    2021-11-09 15:11:57
# ..                   ...
# 224  2021-11-09 16:04:00
# 225  2021-11-09 16:04:26
# 226  2021-11-09 16:04:43
# 227  2021-11-09 16:04:43
# 228  2021-11-09 16:04:31
#
# [229 rows x 18 columns]

# %% [markdown]
# # 時系列での可視化
# ---

# %% [markdown]
# ## 時間毎の出現回数変化
# ---

# %% [markdown]
# ### 受信サイズ, 受信数

# %%
# 時刻, 受信サイズ, 受信数
df_p_ts = df_p[["時刻","受信サイズ", "受信数"]]
df_p_ts = df_p_ts.set_index('時刻')
df_p_ts
# Out:
#           受信サイズ  受信数
# 時刻
# 15:02:16     77    5
# 15:02:32     77    5
# 15:07:49     77    5
# 15:11:40     55    4
# 15:11:57     76    5
# ...         ...  ...
# 16:04:00     67    5
# 16:04:26     70    5
# 16:04:43     68    5
# 16:04:43     68    5
# 16:04:31     61    4
#
# [229 rows x 2 columns]

# %%
# グラフ領域を準備
def plot_init(title):
    fig = plt.figure()
    ax = fig.add_subplot(3,1,1)
    ax.set_title(title)
    return fig, ax

# %%
# プロット
def plot_count_of_day(df_p_ts):
    title = '時刻による変化'
    fig, ax = plot_init(title)
    for c in df_p_ts.columns:
        df_p_ts[c].plot(label=c, ax=ax)
    ax.legend()
    ax.set(xlabel='時刻', ylabel='count')

# %%
rcParams['figure.figsize'] = 20, 20
plot_count_of_day(df_p_ts)
# Out:
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 26178 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 21051 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12395 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12424 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12427 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 22793 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 21270 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 21463 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 20449 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12469 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12474 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 26178 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 21051 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12395 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12424 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12427 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 22793 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 21270 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 21463 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 20449 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12469 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12474 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# 子ユーザ別に時系列表示する意味はありそうか？

# %% [markdown]
# ### 受信サイズ, 返却数

# %%
# 時刻, 受信サイズ, 返却数
df_p_ts = df_p[["時刻","受信サイズ", "返却数"]]
df_p_ts = df_p_ts.set_index('時刻')
df_p_ts
# Out:
#           受信サイズ  返却数
# 時刻
# 15:02:16     77    1
# 15:02:32     77    1
# 15:07:49     77    1
# 15:11:40     55   44
# 15:11:57     76    1
# ...         ...  ...
# 16:04:00     67    2
# 16:04:26     70    1
# 16:04:43     68    1
# 16:04:43     68    1
# 16:04:31     61    0
#
# [229 rows x 2 columns]

# %%
rcParams['figure.figsize'] = 20, 20
plot_count_of_day(df_p_ts)
# Out:
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 26178 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 21051 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12395 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12424 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12427 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 22793 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 21270 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 21463 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 20449 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12469 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12474 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 36820 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 21364 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 26178 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 21051 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12395 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12424 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12427 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 22793 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 21270 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 21463 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 20449 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12469 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12474 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 36820 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 21364 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# 子ユーザ別に時系列表示する意味はありそうか？

# %% [markdown]
# # 相関係数

# %%
df_p.head()
# Out:
#            月日        時刻    子ユーザ          入力値        コマンド  受信サイズ  受信数  返却数  \
# 0  2021-11-09  15:02:16  221002  122905R0004  価格検索（HTTP）     77    5    1
# 1  2021-11-09  15:02:32  221002  122905R0004  価格検索（HTTP）     77    5    1
# 2  2021-11-09  15:07:49  221002  122905R0004  価格検索（HTTP）     77    5    1
# 3  2021-11-09  15:11:40  221002        SD29T  車輌検索（HTTP）     55    4   44
# 4  2021-11-09  15:11:57  221002   R20618300E  価格検索（HTTP）     76    5    1
#
#                 ParamList           parHinban  ...  parHMCount  \
# 0                ['', '']  ['12290-5R0-004 ']  ...         NaN
# 1                ['', '']  ['12290-5R0-004 ']  ...         NaN
# 2                ['', '']  ['12290-5R0-004 ']  ...         NaN
# 3  ['', '', 'SD29T', ' ']            ['', '']  ...         NaN
# 4                ['', '']   ['R206-18-300E ']  ...         NaN
#
#                                           KurumaInfo parJunsei  parType  \
# 0                                           ['', '']       0.0      NaN
# 1                                           ['', '']       0.0      NaN
# 2                                           ['', '']       0.0      NaN
# 3  ['24455', '4', 'ﾏﾂﾀﾞ', '8', 'ﾌﾞﾛｰﾆｨ2200DSL', '...       NaN      NaN
# 4                                           ['', '']       0.0      NaN
#
#   parMakerNo  parHinmokuNos parMakerNos parSyadaiNo  CallHinban  \
# 0        0.0       ['', '']    ['', '']         NaN         NaN
# 1        0.0       ['', '']    ['', '']         NaN         NaN
# 2        0.0       ['', '']    ['', '']         NaN         NaN
# 3        NaN       ['', '']    ['', '']         NaN         NaN
# 4        0.0       ['', '']    ['', '']         NaN         NaN
#
#                   date
# 0  2021-11-09 15:02:16
# 1  2021-11-09 15:02:32
# 2  2021-11-09 15:07:49
# 3  2021-11-09 15:11:40
# 4  2021-11-09 15:11:57
#
# [5 rows x 21 columns]

# %%
df_p_cor = df_p[["受信サイズ", "受信数", "返却数"]]

# %%
df_p_cor
# Out:
#      受信サイズ  受信数  返却数
# 0       77    5    1
# 1       77    5    1
# 2       77    5    1
# 3       55    4   44
# 4       76    5    1
# ..     ...  ...  ...
# 224     67    5    2
# 225     70    5    1
# 226     68    5    1
# 227     68    5    1
# 228     61    4    0
#
# [229 rows x 3 columns]

# %%
#相関係数を算出
use_data = df_p_cor.corr()

# %%
rcParams['figure.figsize'] = 5, 5
sns.heatmap(use_data, cmap="RdBu_r")
# Out:
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 21463 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 20449 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12469 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12474 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 36820 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 21364 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 21463 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 20449 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12469 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12474 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 36820 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\edge\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 21364 missing from current font.
#   font.set_text(s, 0, flags=flags)
# <AxesSubplot:>

# %% [markdown]
# # （再掲）
# ## 0. 目的
# - V8LOGデータ集計の進捗報告
#   - 集計方法の妥当性確認
#   - 可視化方法の確認
#
# ## 1. 進捗
#
# ### 前処理プログラム作成
# - 使用する列の抽出
#   - すべてNullのカラムは削除
#   - すべて同一のカラムは削除
#   - 過半数がNullのカラムは削除
#   - 不要な（あまり見ていない）カラムは削除
# - 「パラメータ等」列の分割
#   - 同一カラムに複数パラメータが入っている為、データ集計しやすいカラム、要素に分割する処理を作成
#
# ### 基礎集計
# - 単純集計
# - 可視化
#   - 棒グラフ
#   - ヒストグラム
#   - 時系列
#
# ## 2. 作成中
# - 同一子ユーザが短い間隔で検索した場合、除外するまたはまとめる
# -　相関のあるカラムの可視化
#   - 相関係数、有意差
# - 時間を指定して基礎集計、基本統計量を出力、可視化
#
# ## 3. 検証ポイント
# - レコード数を増やした場合、現在（1000レコード）と異なる特徴はみられるか
# - 同一子ユーザが短い間隔で検索した影響を除外した場合、現在と異なる特徴はみられるか
# - 相関（有意差）をみたい項目はあるか
# - 時系列で比較したい項目はあるか
#   - 今回は受信サイズ, 受信数でサンプル可視化
#   - 相関の高い項目を時系列で比較してみる等
